# %% [markdown]
# # Урок 1

# %% [markdown]
# # Линейное пространство. Основные понятия. Часть 1

# %%
import numpy as np
from numpy.linalg import norm

# %% [markdown]
# ## Практическое задание

# %% [markdown]
# __1.__ Исследовать на линейную зависимость:
#
# $$f_{1}(x)=e^{x}, f_{2}(x)=1, f_{3}(x)=x+1, f_{4}(x)=x-e^{x}.$$
#
# Система из четырех функий линейно **зависима**, т.к. четвертый вектор является линейной комбинацией остальных векторов.

# %% [markdown]
# __2.__ Исследовать на линейную зависимость:
# $$f_{1}(x)=2, f_{2}(x)=x, f_{3}(x)=x^{2}, f_{4}(x)=(x+1)^{2}$$

# %% [markdown]
# $$ f_4(x) - f_3(x) - 2 f_2(x) - \frac{1}{2} f_1(x) = 0 ~~ \forall x \in \mathbb{R}. $$

# %% [markdown]
# Система линейно **зависима**.

# %% [markdown]
# __3.__ Найти координаты вектора $x = (2, 3, 5)\in \mathbb{R}^{3}$ в базисе $b_{1}=(0, 0, 10)$, $b_{2}=(2, 0, 0)$, $b_{3}=(0, 1, 0)$.

# %% [markdown]
# $$ x = \frac{2}{|b_2|} b_2 + \frac{3}{|b_3|} b_3 + \frac{5}{|b_1|} b_1 = \frac{5}{10} b_1 + \frac{2}{2} b_2 + \frac{3}{1} b_3 = {\left(\frac{1}{2}, 1, 3 \right)}$$

# %% [markdown]
# __4.__ Найти координаты вектора $3x^{2}-2x+2\in\mathbb{R}^{3}[x]$:
#
# а) в базисе $1$, $x$, $x^{2}$;
#
# б) в базисе $x^{2}$, $x-1$, $1$.

# %% [markdown]
# а) $$ v = (2, -2, 3) $$

# %% [markdown]
# б) $$ v_0 \cdot x^2 + v_1 \cdot (x-1) + v_2 \cdot 1 = 3 x^2 - 2x + 2 $$
#
# $$ v_0 = 3; v_1 = - 2; v_2 - v_1 = 2. $$
#
# $$ v_0 = 3; v_1 = -2; v_2 = 0 $$
#
# $$ v = {\left(3, -2, 0 \right)}_{b} $$

# %% [markdown]
# __5.__ Установить, является ли линейным подпространством:
#
# а) совокупность всех векторов трехмерного пространства, у которых по крайней мере одна из первых двух координат равна нулю;
#
# б) все векторы, являющиеся линейными комбинациями данных векторов $\{u_{1}, u_{2}, \ldots, u_{n}\}$.

# %% [markdown]
# а)  Можно найти контрпример, где результирующий вектор не будет иметь нулевого значения ни в первой координате, ни во второй, поэтому **не является**<br>
# б) **Является**, т.к. линейная комбинация векторов подпространства выражается через линейную комбинацию опорных векторов

# %% [markdown]
# # Урок 2
#
# # Линейное пространство. Основные понятия. Часть 2
#
# ## Практическое задание
#
# __1.__ Найти скалярное произведение векторов $x, y \in \mathbb{R}$:<br>
# а) $x=(0,-3, 6),~y=(-4, 7, 9);$<br>
# б) $x=(7, -4, 0, 1),~y=(-3, 1, 11, 2).$

# %%
x_a = np.array([0,-3,6])
y_a = np.array([-4,7,9])
x_a @ y_a
# Out:
# 33

# %%
x_b = np.array([7,-4,0,1])
y_b = np.array([-3,1,11,2])
x_b @ y_b
# Out:
# -23

# %% [markdown]
# __2.__ Найти нормы векторов $(4, 2, 4)$ и $(12, 3, 4)$ и угол между ними.

# %%
x = np.array([4,2,4])
y = np.array([12,3,4])
norm(x), norm(y), np.degrees(np.arccos(x @ y / norm(x) / norm(y)))
# Out:
# (6.0, 13.0, 26.176952171666557)

# %% [markdown]
# __3.__ Будет ли линейное пространство евклидовым, если за скалярное произведение принять:<br>
# а) произведение длин векторов;<br>
# б) утроенное обычное скалярное произведение векторов?<br>

# %% [markdown]
# а) **Нет**, не хватает произведения на косинус угла между векторами<br>
# б) **Да**, будет

# %% [markdown]
# __4.__ Какие из нижеперечисленных векторов образуют ортонормированный базис в линейном пространстве $\mathbb{R}^{3}$:<br>
# а) $(1,0,0),(0,0,1);$ <br>
# б) $(1/\sqrt{2},-1/\sqrt{2},0),(1/\sqrt{2},1/\sqrt{2},0), (0,0,1);$<br>
# в) $(1/2, -1/2, 0), (0, 1/2, 1/2), (0,0,1);$<br>
# г) $(1,0,0),(0,1,0),(0,0,1)?$

# %% [markdown]
# **б)** и **г)** - т.к. базисы
